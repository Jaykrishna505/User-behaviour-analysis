# %%
pip install markovclick
# Out:
# Requirement already satisfied: markovclick in /usr/local/lib/python3.6/dist-packages (0.1.2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#    Users    1   2   3   4   5   6   7  ...  103  104  105  106  107  108  109  110
# 0  User1   A1  A1  A1  A1  A1  A1  A1  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  User2   A1  A1  A1  A2  A1  A3  A4  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  User3   A1  A1  A1  A1  A1  A1  A1  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  User4   A1  A1  A1  A1  A1  A1  A9  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  User5  A12  A1  A1  A1  A5  A5  A5  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 111 columns]

# %%
df.set_index(df.columns[0],inplace=True)

# %%
df.head()
# Out:
#          1   2   3   4   5   6   7    8  ...  103  104  105  106  107  108  109  110
# Users                                    ...
# User1   A1  A1  A1  A1  A1  A1  A1   A1  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# User2   A1  A1  A1  A2  A1  A3  A4   A5  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# User3   A1  A1  A1  A1  A1  A1  A1   A4  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# User4   A1  A1  A1  A1  A1  A1  A9   A1  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# User5  A12  A1  A1  A1  A5  A5  A5  A13  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 110 columns]

# %%
data=[]
for i in range(100):
    x=df.values[i]
    x=x[~pd.isnull(x)]
    data.append(x)
data
# Out:
# [array(['A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A2', 'A1', 'A3', 'A4', 'A5', 'A6', 'A1', 'A7',
#         'A4', 'A8', 'A4', 'A1', 'A1', 'A3', 'A5', 'A7', 'A7'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A4', 'A5', 'A5', 'A5',
#         'A4', 'A9', 'A1', 'A1', 'A29', 'A4', 'A5', 'A6'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A9', 'A1', 'A1', 'A9', 'A10',
#         'A9', 'A11', 'A11', 'A11', 'A8', 'A1'], dtype=object),
#  array(['A12', 'A1', 'A1', 'A1', 'A5', 'A5', 'A5', 'A13', 'A13', 'A1',
#         'A14', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A12', 'A12', 'A12', 'A12', 'A12', 'A1', 'A15', 'A1', 'A16',
#         'A16', 'A17', 'A18', 'A18', 'A19', 'A6', 'A1'], dtype=object),
#  array(['A12', 'A2', 'A1', 'A4', 'A1', 'A4', 'A1', 'A4', 'A14', 'A4', 'A1',
#         'A4', 'A1', 'A20', 'A4', 'A5', 'A4', 'A1', 'A6', 'A6', 'A7', 'A9'],
#        dtype=object),
#  array(['A1', 'A6', 'A1', 'A15', 'A1', 'A1', 'A1', 'A1', 'A15', 'A21',
#         'A1', 'A21', 'A4', 'A9', 'A9', 'A1', 'A9', 'A1', 'A30', 'A6', 'A8'],
#        dtype=object),
#  array(['A5', 'A4', 'A1', 'A5', 'A4', 'A5', 'A4', 'A1', 'A5', 'A4', 'A1',
#         'A1', 'A22', 'A1', 'A9', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A7', 'A9', 'A9', 'A10', 'A11', 'A12',
#         'A13', 'A14'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A2', 'A3',
#         'A5', 'A7', 'A5', 'A5'], dtype=object),
#  array(['A1', 'A21', 'A4', 'A9', 'A1', 'A1', 'A1', 'A10', 'A10', 'A9',
#         'A11', 'A11', 'A4', 'A9', 'A14', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A13', 'A1', 'A8', 'A1', 'A1', 'A5', 'A7', 'A8',
#         'A9', 'A10', 'A10', 'A11', 'A11'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A23', 'A24', 'A22', 'A20', 'A4', 'A2', 'A6', 'A25', 'A6', 'A1',
#         'A12', 'A12', 'A2', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A7', 'A22', 'A2', 'A1', 'A1', 'A1', 'A12', 'A15', 'A9',
#         'A15', 'A15', 'A1'], dtype=object),
#  array(['A22', 'A22', 'A2', 'A1', 'A1', 'A2', 'A2', 'A3', 'A3'],
#        dtype=object),
#  array(['A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1'], dtype=object),
#  array(['A11', 'A11', 'A11', 'A2', 'A24', 'A24', 'A24', 'A1'], dtype=object),
#  array(['A1', 'A9', 'A26', 'A26', 'A2', 'A1', 'A1', 'A1', 'A1', 'A1'],
#        dtype=object),
#  array(['A15', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A15', 'A1', 'A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A2'], dtype=object),
#  array(['A5', 'A6', 'A27', 'A12', 'A1', 'A6', 'A6', 'A12', 'A1', 'A20',
#         'A1', 'A14', 'A1'], dtype=object),
#  array(['A4', 'A1', 'A13', 'A13', 'A4', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A5', 'A4', 'A1', 'A1', 'A1', 'A4', 'A27', 'A27', 'A8',
#         'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A2', 'A12', 'A2', 'A3', 'A2', 'A28', 'A2', 'A8', 'A2', 'A27',
#         'A2', 'A22', 'A2', 'A7', 'A6', 'A5', 'A6', 'A2', 'A11', 'A2',
#         'A27', 'A2', 'A3', 'A2', 'A26', 'A2', 'A15', 'A2', 'A1'],
#        dtype=object),
#  array(['A1', 'A10', 'A9', 'A8', 'A8', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A3', 'A4'], dtype=object),
#  array(['A29', 'A29', 'A13', 'A13', 'A13', 'A1'], dtype=object),
#  array(['A1', 'A32', 'A5'], dtype=object),
#  array(['A4', 'A9', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A24', 'A10', 'A9', 'A5', 'A5', 'A4', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A9', 'A1', 'A1', 'A22', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A8', 'A1', 'A15', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A2', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A20', 'A20', 'A14', 'A14', 'A14', 'A30', 'A30', 'A31', 'A31',
#         'A31', 'A32', 'A32', 'A32', 'A33', 'A33', 'A29', 'A29', 'A30',
#         'A30', 'A30', 'A13', 'A13', 'A13', 'A32', 'A32', 'A32', 'A34',
#         'A34', 'A31', 'A31', 'A5', 'A5', 'A32', 'A32', 'A31', 'A31', 'A29',
#         'A29', 'A31', 'A31', 'A30', 'A30', 'A20', 'A20', 'A5', 'A5', 'A31',
#         'A31', 'A34', 'A34', 'A34', 'A13', 'A13', 'A31', 'A31', 'A14',
#         'A14', 'A33', 'A33', 'A29', 'A29', 'A32', 'A32', 'A29', 'A29',
#         'A5', 'A5', 'A5', 'A20', 'A20', 'A20', 'A32', 'A32', 'A32', 'A34',
#         'A34', 'A13', 'A13', 'A13', 'A13', 'A20', 'A20', 'A20', 'A31',
#         'A31', 'A32', 'A32', 'A31', 'A31', 'A30', 'A30', 'A13', 'A13',
#         'A32', 'A32', 'A14', 'A14', 'A31', 'A31', 'A14', 'A14', 'A14',
#         'A34', 'A34', 'A5', 'A5', 'A32', 'A32', 'A32', 'A20'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A10', 'A9', 'A11', 'A11', 'A2', 'A1', 'A1', 'A1', 'A1', 'A1'],
#        dtype=object),
#  array(['A1'], dtype=object),
#  array(['A12', 'A15', 'A1', 'A1', 'A1', 'A2', 'A2'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A36', 'A10', 'A9', 'A15', 'A15', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A12', 'A1', 'A5', 'A1'], dtype=object),
#  array(['A9', 'A10', 'A9', 'A15', 'A15', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A4', 'A9', 'A10', 'A9', 'A27', 'A27', 'A4', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A2', 'A6', 'A2', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A15'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A14'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1'], dtype=object),
#  array(['A13', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A30', 'A5', 'A22', 'A22', 'A13', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A13', 'A32', 'A32', 'A13', 'A1', 'A30', 'A22', 'A15', 'A1', 'A29',
#         'A20', 'A20', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A8', 'A1'], dtype=object),
#  array(['A20', 'A4', 'A1'], dtype=object),
#  array(['A37', 'A4', 'A1', 'A4', 'A1', 'A6', 'A2', 'A1'], dtype=object),
#  array(['A22', 'A30', 'A30', 'A5', 'A22', 'A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1', 'A13', 'A1', 'A15', 'A1', 'A5', 'A1', 'A1', 'A1'],
#        dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A37', 'A12', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A2', 'A28', 'A2', 'A15', 'A2', 'A12', 'A2', 'A11', 'A2', 'A1'],
#        dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1', 'A8', 'A1', 'A5', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A2', 'A3', 'A2', 'A2'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A1', 'A2', 'A1', 'A1', 'A1', 'A2', 'A1'],
#        dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A9', 'A1', 'A1', 'A1', 'A8', 'A1', 'A15',
#         'A1', 'A1', 'A1', 'A1', 'A1', 'A1'], dtype=object)]

# %%
from markovclick.models import MarkovClickstream
m = MarkovClickstream(data)

# %%
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='r', edgecolor='k')
sns.heatmap(m.prob_matrix, xticklabels=m.pages, yticklabels=m.pages,cmap="YlGnBu")

# %%
from markovclick.viz import visualise_markov_chain
graph = visualise_markov_chain(m)

# %%
print(graph.source)
# Out:
# digraph {
# 	A1 [label=A1 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A1 -> A1 [label=0.66 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A1 -> A15 [label="   0.04" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A10 [label=A10 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A10 -> A9 [label=0.67 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A10 -> A10 [label="   0.17" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A11 [label=A11 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A11 -> A11 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A11 -> A2 [label="   0.29" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A12 [label=A12 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A12 -> A1 [label=0.33 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A12 -> A12 [label="   0.28" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A13 [label=A13 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A13 -> A13 [label=0.44 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A13 -> A1 [label="   0.28" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A14 [label=A14 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A14 -> A14 [label=0.43 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A14 -> A1 [label="   0.21" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A15 [label=A15 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A15 -> A1 [label=0.63 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A15 -> A15 [label="   0.16" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A16 [label=A16 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A16 -> A17 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A16 -> A16 [label="   0.50" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A17 [label=A17 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A17 -> A18 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A17 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A17 -> A17 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A18 [label=A18 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A18 -> A19 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A18 -> A18 [label="   0.50" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A19 [label=A19 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A19 -> A6 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A19 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A19 -> A19 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A2 [label=A2 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A2 -> A1 [label=0.36 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A2 -> A3 [label="   0.13" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A2 -> A2 [label="   0.08" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A20 [label=A20 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A20 -> A20 [label=0.44 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A20 -> A4 [label="   0.19" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A21 [label=A21 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A21 -> A4 [label=0.67 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A21 -> A1 [label="   0.33" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A21 -> A21 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A22 [label=A22 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A22 -> A1 [label=0.25 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A22 -> A2 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A22 -> A22 [label="   0.17" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A23 [label=A23 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A23 -> A24 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A23 -> A8 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A23 -> A23 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A24 [label=A24 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A24 -> A24 [label=0.40 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A24 -> A22 [label="   0.20" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A25 [label=A25 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A25 -> A6 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A25 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A25 -> A25 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A26 [label=A26 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A26 -> A2 [label=0.67 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A26 -> A26 [label="   0.33" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A27 [label=A27 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A27 -> A27 [label=0.29 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A27 -> A2 [label="   0.29" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A28 [label=A28 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A28 -> A2 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A28 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A28 -> A28 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A29 [label=A29 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A29 -> A29 [label=0.42 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A29 -> A32 [label="   0.08" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A3 [label=A3 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A3 -> A2 [label=0.38 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A3 -> A5 [label="   0.25" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A3 -> A3 [label="   0.12" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A30 [label=A30 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A30 -> A30 [label=0.43 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A30 -> A5 [label="   0.14" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A31 [label=A31 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A31 -> A31 [label=0.53 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A31 -> A32 [label="   0.11" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A32 [label=A32 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A32 -> A32 [label=0.57 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A32 -> A34 [label="   0.09" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A33 [label=A33 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A33 -> A33 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A33 -> A29 [label="   0.50" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A34 [label=A34 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A34 -> A34 [label=0.56 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A34 -> A13 [label="   0.22" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A36 [label=A36 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A36 -> A10 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A36 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A36 -> A36 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A37 [label=A37 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A37 -> A12 [label=0.50 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A37 -> A4 [label="   0.50" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A37 -> A37 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A4 [label=A4 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A4 -> A1 [label=0.53 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A4 -> A9 [label="   0.19" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A4 -> A4 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A5 [label=A5 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A5 -> A5 [label=0.31 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A5 -> A4 [label="   0.22" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A6 [label=A6 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A6 -> A1 [label=0.27 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A6 -> A2 [label="   0.20" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A6 -> A6 [label="   0.13" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A7 [label=A7 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A7 -> A9 [label=0.25 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A7 -> A7 [label="   0.12" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A8 [label=A8 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A8 -> A1 [label=0.67 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A8 -> A4 [label="   0.08" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A8 -> A8 [label="   0.08" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A9 [label=A9 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A9 -> A1 [label=0.33 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A9 -> A10 [label="   0.19" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A9 -> A9 [label="   0.07" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# }

# %%
graph.render('test-output/round-table.gv', view=True)
# Out:
# 'test-output/round-table.gv.pdf'

# %%
graph
